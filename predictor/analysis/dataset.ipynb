# %%
# Basic Data Analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# get data
data_path = "../dataset/"
data = pd.read_csv(data_path + 'AAPL.csv')
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

data.head()
# Out:
#             Timestamp     Open     High      Low    Close  Volume    SMA_10  \
# 0 2022-01-03 04:00:00  176.023  176.127  175.502  175.849    9876  175.8868
# 1 2022-01-03 04:15:00  175.846  175.909  175.552  175.593    9992  175.8868
# 2 2022-01-03 04:30:00  175.638  175.682  175.502  175.662    9560  175.8868
# 3 2022-01-03 04:45:00  175.648  175.890  175.552  175.849   10339  175.8868
# 4 2022-01-03 05:00:00  175.846  175.949  175.729  175.859   10041  175.8868
#
#      SMA_50  SMA_100    EMA_10    EMA_50  EMA_100  RSI_10   RSI_50  RSI_100  \
# 0  177.8612  178.816  175.8868  177.8612  178.816  59.528  64.8586  53.1615
# 1  177.8612  178.816  175.8868  177.8612  178.816  59.528  64.8586  53.1615
# 2  177.8612  178.816  175.8868  177.8612  178.816  59.528  64.8586  53.1615
# 3  177.8612  178.816  175.8868  177.8612  178.816  59.528  64.8586  53.1615
# 4  177.8612  178.816  175.8868  177.8612  178.816  59.528  64.8586  53.1615
#
#        VWAP    MACD  MACD_Hist  MACD_Signal
# ...

# %%
year_data = data[data['Timestamp'].dt.year == 2022]
month_data = data[data['Timestamp'].dt.month == 3]
day_data = data[data['Timestamp'] >= '2022-03-01']
day_data = day_data[day_data['Timestamp'] <= '2022-03-02']

# %%
# plot OHLC



fig = plt.figure(figsize=(10, 5))

# Plot OHLC
plt.plot(day_data["Timestamp"], day_data['Open'], label='Open')
plt.plot(day_data["Timestamp"], day_data['High'], label='High')
plt.plot(day_data["Timestamp"], day_data['Low'], label='Low')
plt.plot(day_data["Timestamp"], day_data['Close'], label='Close')

# Plot Volume as bar graph with secondary y-axis
ax2 = plt.twinx()
ax2.set_ylim([0, 20000000])
ax2.bar(day_data["Timestamp"], day_data['Volume'], label='Volume', alpha=0.8, width=0.008)

plt.title('2022-03-01 AAPL OHLC')
plt.xlabel('Date')
plt.ylabel('Price')

# Set legends for both plots
lines, labels = fig.axes[0].get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines + lines2, labels + labels2)

plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

plot_data = day_data
title_date = '2022-03-01' if plot_data is day_data else '2022-03'

# Plot OHLC
# plt.plot(plot_data['Timestamp'], plot_data['SMA_100'], label='SMA_100')
# plt.plot(plot_data['Timestamp'], plot_data['SMA_50'], label='SMA_50')
plt.plot(plot_data['Timestamp'], plot_data['SMA_10'], label='SMA_10')
# plt.plot(plot_data['Timestamp'], plot_data['EMA_100'], label='EMA_100')
# plt.plot(plot_data['Timestamp'], plot_data['EMA_50'], label='EMA_50')
plt.plot(plot_data['Timestamp'], plot_data['EMA_10'], label='EMA_10')
plt.plot(plot_data['Timestamp'], plot_data['Close'], label='Close')

plt.title(title_date + ' AAPL Close & SMA & EMA')
plt.xlabel('Date')
plt.ylabel('Price')

# Set legends for both plots
lines, labels = fig.axes[0].get_legend_handles_labels()
plt.legend()

plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

plot_data = month_data
title_date = '2022-03-01' if plot_data is day_data else '2022-03'

# Plot OHLC
# plt.plot(plot_data['RSI_100'], label='RSI_100')
plt.plot(plot_data['RSI_50'], label='RSI_50')
# plt.plot(plot_data['RSI_10'], label='RSI_10')

ax2 = plt.twinx()
ax2.plot(plot_data['Close'], label='Close', color='orange')

plt.title(title_date + ' AAPL Close & RSI')
plt.xlabel('Date')
plt.ylabel('Price')

# Set legends for both plots
lines, labels = fig.axes[0].get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines + lines2, labels + labels2)

plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

plot_data = day_data
title_date = '2022-03-01' if plot_data is day_data else '2022-03'

# Plot OHLC
plt.plot(plot_data['VWAP'], label='VWAP', color='royalblue')
plt.plot(plot_data['Close'], label='Close', color='orange')

ax2 = plt.twinx()
ax2.bar(np.linspace(0, len(plot_data), len(plot_data)), plot_data['Volume'], label='Volume')

plt.title(title_date + ' AAPL Close & VWAP & Volume')
plt.xlabel('Date')
plt.ylabel('Price')

# Set legends for both plots
lines, labels = fig.axes[0].get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines + lines2, labels + labels2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/tmp/ipykernel_3552/1830320298.py in <module>
#       9
#      10 ax2 = plt.twinx()
# ---> 11 ax2.bar(plot_data['Volume'], label='Volume')
#      12
#      13 plt.title(title_date + ' AAPL Close & VWAP & Volume')
#
# ~/trader_ai/trader_ai/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.figure(figsize=(10, 2))
plt.bar(data['Timestamp'], data['Volume'], label='Volume', width=0.1)
plt.title('2022-03-01 AAPL OHLC')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Timestamp,Open,High,Low,Close,Volume,SMA_10,SMA_50,SMA_100,EMA_10,EMA_50,EMA_100,RSI_10,RSI_50,RSI_100,VWAP,MACD,MACD_Hist,MACD_Signal
